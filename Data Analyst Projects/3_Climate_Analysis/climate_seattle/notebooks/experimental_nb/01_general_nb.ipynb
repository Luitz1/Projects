# %%
import sys
from pathlib import Path

# Agregar la ruta del proyecto al sys.path para importar scripts
sys.path.append(str(Path().resolve().parents[1] / "scripts"))

# %% [markdown]
# ### Recargar paths
#
# Si hay fallas en modulos o importacion, se puede recargar el cache del jnb

# %%
import importlib
import paths
importlib.reload(paths)
# Out:
# <module 'paths' from '/home/kidd01/Documentos/cookiecutter_plantillas/cookiecutter-data_project/climate_seattle/scripts/paths.py'>

# %% [markdown]
# ### Paths disponibles

# %%
from paths import Paths
for i in list(Paths.summary().keys()): print(i)
# Out:
# DATA
# DATA_EXTERNAL
# DATA_PROCESSED
# DATA_RAW
# MODELS_DIR
# NOTEBOOKS_DIR
# OUT_DIR
# OUT_FIGURES
# OUT_REPORTS
# README
# REQUIREMENTS
# ROOT_DIR
# SCRIPTS_DIR
# TOOLS_DIR
